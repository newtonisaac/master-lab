# %%
test_endpoint='http://node.default.127.0.0.1.nip.io/'
target='local'
simulation_identifier='teste2'

# %%
! ../k6_scripts/run_load.sh t1 $test_endpoint $target $simulation_identifier
# Out:
# Running Teste de sobrecarga (T1) - http://node.default.127.0.0.1.nip.io/ - local - identifier=teste2
#
#           /\      |‾‾| /‾‾/   /‾‾/
#      /\  /  \     |  |/  /   /  /
#     /  \/    \    |     (   /   ‾‾\
#    /          \   |  |\  \ |  (‾)  |
#   / __________ \  |__| \__\ \_____/ .io
#
#   execution: local
#      script: /home/jovyan/k6_scripts/t1.js
#      output: InfluxDBv1 (http://localhost:8086)
#
#   scenarios: (100.00%) 1 scenario, 1 max VUs, 50s max duration (incl. graceful stop):
#            * t1: 1 looping VUs for 20s (gracefulStop: 30s)
#
#
# running (00.1s), 1/1 VUs, 0 complete and 0 interrupted iterations
# t1     [--------------------------------------] 1 VUs  00.1s/20s
#
# running (00.2s), 1/1 VUs, 0 complete and 0 interrupted iterations
# t1     [--------------------------------------] 1 VUs  00.2s/20s
#
# running (00.3s), 1/1 VUs, 0 complete and 0 interrupted iterations
# t1     [--------------------------------------] 1 VUs  00.3s/20s
#
# ...

# %%
from influxdb import DataFrameClient
import seaborn
import matplotlib.pyplot as plt
import pandas as pd

# %%
client = DataFrameClient('localhost', 8086, 'admin', 'admin', 'k6')

res = client.query("SELECT * FROM 'checks','vus','http_req_duration' WHERE simulation='teste2')"
# A dict of metrics is returns
res = res['http_req_duration']
res
# Out:
#   File "/tmp/ipykernel_44/356668783.py", line 3
#     res = client.query("SELECT * FROM 'checks','vus','http_req_duration' WHERE simulation='teste2')
#                                                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
seaborn.lineplot(data=res)
plt.show()
